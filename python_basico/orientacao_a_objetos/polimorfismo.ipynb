# %% [markdown]
# # O que é?
#
# A palavra polimorfismo significa ter muitas formas. Na programação, polimorfismo significa o mesmo nome de função (mas assinaturas diferentes) sendo usado para diferentes tipos.
#
# ## Na herança
#
# Na herança, a classe filha herda os métodos da classe pai. No entanto, é possível modificar um método em uma classe filha herdado da classe pai. Isso é particularmente útil nos casos em que o método herdado da classe pai não se encaixa perfeitamente na classe filha.

# %%
class Passaro:
	def voar(self):
		print("Iiiiiioooooonnn")
				
class Pardal(Passaro):
    def voar(self):
        print(f"{self.__class__.__name__} pode voar")
				
class Avestruz(Passaro):
	def voar(self):
		print(f"{self.__class__.__name__} não voa")
		
class Aviao(Passaro):
	pass
			
def plano_voo(passaro):
	passaro.voar()
		
plano_voo(Pardal()) # "Pardal voa"
plano_voo(Avestruz()) # "Avestruz não voa"
plano_voo(Aviao()) # inventei
# Out:
# Pardal pode voar
# Avestruz não voa
# Iiiiiioooooonnn
